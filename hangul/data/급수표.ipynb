# %%
import hgtk
import re
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_excel('1학년1학기.xlsx')
df
# Out:
#    No      1급      2급   3급       4급       5급       6급          7급         8급  \
# 0   1      우리      친구   나무     나의 꿈  다녀오겠습니다  학교 가는 길         목소리      밥 달라고
# 1   2       나    내 친구   노루  김슬기 입니다     어머니께     아기나무         개나리        꿀꿀꿀
# 2   3      너      정다운  너구리      그림을  인사를 합니다     어서어서         울타리       오냐오냐
# 3   4     아버지     선생님   거미  잘 그립니다.      길에서      자라서          오리       알았다고
# 4   5      가족    고마우신    소      화가가     친구를    무엇이 될까        한 마리     춤을 추어요
# 5   6     어머니      학교    파  되고 싶습니다     만납니다      자라면    시냇물이 졸졸졸   고개를 끄덕끄덕
# 6   7      아기   우리 학교   고추       모자   수진아 안녕   큰 나무되지  바람개비가 뱅글뱅글   어깨를 으쓱으쓱
# 7   8   우리 아기  즐거운 학교   오리       나비   진수야 안녕     우리는         엄마돼지  엉덩이를 흔들흔들
# 8   9   우리 가족   모두 모여   하마    아침입니다       함께      자라라        아기돼지   덩실덩실 신나게
# 9  10  우리는 하나  우리는 하나  고구마      학교에      갑니다      꾀꼬리        토실토실       방글방글
#
#         9급  ...            21급             22급             23급            24급  \
# ...

# %%
list=[]
list = df['30급'].values.tolist
print(type(list))
# Out:
# <class 'builtin_function_or_method'>

# %%
tot_list=df.values.tolist()
tot_list
# Out:
# [['No',
#   '1급',
#   '2급',
#   '3급',
#   '4급',
#   '5급',
#   '6급',
#   '7급',
#   '8급',
#   '9급',
#   '10급',
#   '11급',
#   '12급',
#   '13급',
#   '14급',
#   '15급',
#   '16급',
#   '17급',
#   '18급',
#   '19급',
#   '20급',
#   '21급',
#   '22급',
#   '23급',
#   '24급',
#   '25급',
#   '26급',
#   '27급',
#   '28급',
#   '29급',
#   '30급'],
#  [1,
#   '우리',
#   '친구',
#   '나무',
#   '나의 꿈',
#   '다녀오겠습니다',
#   '학교 가는 길',
#   '목소리',
#   '밥 달라고',
#   '풍덩 엄마오리',
#   '잡고 있습니다',
#   '맛있겠다',
#   '받아 들고는 ',
#   '집을 봅니다',
#   '겅중겅중',
#   '우물우물 먹습니다',
#   '우리들은 참새다',
#   '지붕 위에 동동동',
#   '무척 멋있었습니다',
#   '치울 수가 없었습니다.',
#   '마을로 향하였습니다.',
#   '정글짐에서 놀면',
#   '소리를 뽐내는 일',
#   '풀을 꽉 잡았습니다.',
#   '쨍쨍 내리쬐는 햇볕',
#   '눈물을 글썽이었습니다.',
#   '알차게 여물어 갔습니다.',
#   '강아지를 돌보아야 해',
#   '못생긴 모습이 되었어요.',
#   '책받침',
#   '밭에서 일합니다.'],
#  [2,
#   '나',
#   '내 친구',
#   '노루',
#   '김슬기 입니다',
#   '어머니께',
#   '아기나무',
#   '개나리',
#   '꿀꿀꿀',
#   '연못 속에',
#   '꾀 많은 여우가',
#   '나 혼자 먹어야지',
#   '도망을 칩니다',
#   '심심해',
#   '뛰어나옵니다',
# ...

# %%
print(type(tot_list))
# Out:
# <class 'list'>

# %%
list= df['30'].values.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '30'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-4906541e7ffb> in <module>
# ----> 1 list= df['30'].values.tolist()
#
# C:\ANACONDA\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
import hgtk
import re

# %%
hgtk.text.decompose(tot_list[0])
# Out:
# 'No'

# %%
all_list=[]
i = 1

for i in range(0,len(link_list)):
    temp_list.append(link_list[i].split()[0])
print(temp_list)

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'C:\ANACONDA\python.exe -m pip install --upgrade pip' command.
