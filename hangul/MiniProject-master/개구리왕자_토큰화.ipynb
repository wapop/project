# %%
import urllib.request
from konlpy.tag import Okt
from gensim.models.word2vec import Word2Vec
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('개구리왕자.txt',sep = '\t',engine = 'python', header = None, encoding='cp949')

# %%
train.columns= (['A'])

# %%
train
# Out:
#                                                     A
# 0                                           1. 개구리 왕자
# 1   옛날 옛적에 소망을 이루어 주는 힘이 여전히 통했던 때에, 딸들이 모두 예쁜 왕이 ...
# 2   특히나 막내공주님이 아주 예뻤는데요, 어찌나 아름다운지, 해도 그녀의 얼굴에 햇볕을...
# 3                             왕의 성은 울창한 숲에 둘러싸여 있었어요.
# 4                  숲에 있는 나이 많은 라임 나무 아래에 우물이 하나 있었어요.
# ..                                                ...
# 84                                   그래서 뒤돌아보며 소리쳤어요.
# 85                        “헨리(왕자님의 종), 마차가 부서지고 있어.”
# 86  “아닙니다, 주인님, 마차가 아니에요. 제 가슴에서 나는 악기 소리에요. 왕자님이 ...
# 87  마차가 가는 도중에 또다시 그리고 한 번 더 또다시 뭔가가 와장창 깨지는 소리가 났...
# 88  ㅋㅋㅋ 하지만 그건 자신의 주인(=왕자님)이 마법에서 풀려나 행복한 것이 너무도 기...
#
# [89 rows x 1 columns]

# %%
train['A'] = train['A'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# %%
train['A']
# Out:
# 0                                                개구리 왕자
# 1     옛날 옛적에 소망을 이루어 주는 힘이 여전히 통했던 때에 딸들이 모두 예쁜 왕이 한...
# 2     특히나 막내공주님이 아주 예뻤는데요 어찌나 아름다운지 해도 그녀의 얼굴에 햇볕을 비...
# 3                                왕의 성은 울창한 숲에 둘러싸여 있었어요
# 4                     숲에 있는 나이 많은 라임 나무 아래에 우물이 하나 있었어요
#                             ...
# 84                                      그래서 뒤돌아보며 소리쳤어요
# 85                                헨리왕자님의 종 마차가 부서지고 있어
# 86    아닙니다 주인님 마차가 아니에요 제 가슴에서 나는 악기 소리에요 왕자님이 개구리로 ...
# 87    마차가 가는 도중에 또다시 그리고 한 번 더 또다시 뭔가가 와장창 깨지는 소리가 났...
# 88    ㅋㅋㅋ 하지만 그건 자신의 주인왕자님이 마법에서 풀려나 행복한 것이 너무도 기뻤던 ...
# Name: A, Length: 89, dtype: object

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt = Okt()
tokenized_data = []
for sentence in train['A']:
    temp_X = okt.morphs(sentence, stem=True) 
    temp_X = [word for word in temp_X if not word in stopwords] 
    tokenized_data.append(temp_X)

# %%
tokenized_data
# Out:
# [['개구리', '왕자'],
#  ['옛날',
#   '옛적',
#   '소망',
#   '을',
#   '이루다',
#   '주다',
#   '힘',
#   '여전하다',
#   '통',
#   '때',
#   '딸',
#   '모두',
#   '예쁘다',
#   '왕',
#   '분',
#   '살',
#   '고',
#   '계시다'],
#  ['특히',
#   '나',
#   '막내',
#   '공주',
#   '님',
#   '아주',
#   '예쁘다',
#   '어찌나',
#   '아름답다',
#   '해도',
#   '그녀',
#   '얼굴',
#   '햇볕',
#   '을',
#   '비추다',
#   '때',
#   '마다',
#   '감탄',
#   '을',
#   '하곤',
#   '하였더랬',
#   '죠'],
#  ['왕', '성은', '울창', '숲', '둘러싸이다', '있다'],
#  ['숲', '있다', '나이', '많다', '라임', '나무', '아래', '우물', '하나', '있다'],
#  ['화창하다',
#   '날',
#   '막내',
#   '공주',
#   '님',
#   '께서',
#   '숲',
#   '놀다',
#   '나오다',
#   '시원하다',
#   '분수',
#   '옆',
#   '앉다'],
#  ['그녀', '따분하다', '땐', '황금', '공', '을', '가져오다', '높이', '던지다', '다시', '잡다'],
#  ['황금', '공', '놀이', '그녀', '가장', '좋아하다', '놀다'],
#  ['그렇다',
#   '우연히',
#   '공주',
#   '작다',
#   '손',
#   '떠받치다',
#   '있다',
#   '황금',
#   '공이',
#   '바닥',
#   '떨어지다',
#   '곧장',
#   '우물',
#   '속',
#   '구르다',
#   '들어가다',
#   '뭐',
#   '예요'],
#  ['공주', '님', '다급하다', '눈', '으론', '공', '을', '쫓다', '허사', '이다'],
#  ['우물', '꽤', '깊다', '바닥', '보이지', '않다', '정도', '로', '요'],
#  ['일로',
#   '공주',
#   '님',
#   '울다',
#   '시작',
#   '소리',
#   '내',
#   '울',
#   '고',
#   '더',
#   '크게',
#   '소리',
#   '내',
#   '울다',
#   '마음',
#   '안정',
#   '을',
#   '찾다',
#   '수가',
#   '없다'],
#  ['그렇게',
#   '눈물',
#   '을',
#   '글썽',
#   '이고',
#   '있다',
#   '누군가',
#   '그녀',
#   '에게',
#   '이렇게',
#   '말',
#   '거',
#   '예요'],
#  ['누가',
#   '널',
#   '괴롭히다',
#   '공주',
#   '야',
#   '네',
#   '모습',
#   '을',
#   '보고',
#   '돌다',
#   '눈물',
#   '을',
#   '뚝뚝',
#   '흘리다'],
#  ['공주',
#   '목소리',
#   '들려오다',
#   '쪽',
#   '을',
#   '돌아보다',
#   '게',
#   '뭔가',
#   '요',
#   '세상',
#   '에나',
#   '똥똥하다',
#   '못',
#   '생기다',
#   '개구리',
#   '마리',
#   '물',
#   '위로',
#   '고개',
#   '쭉',
#   '내',
#   '밀고',
#   '있다',
#   '뭐',
#   '예요'],
#  ['아아',
#   '넌',
#   '헤엄',
#   '을',
#   '치다',
#   '공주',
#   '말',
#   '우물',
#   '로',
#   '떨어지다',
#   '내',
#   '황금',
#   '공',
#   '때문',
#   '울',
#   '고',
#   '있다',
#   '거야'],
#  ['울',
#   '지',
#   '말고',
#   '뚝',
#   '라며',
#   '개구리',
#   '대답',
#   '내',
#   '널',
#   '도울',
#   '수',
#   '있다',
#   '그렇지만',
#   '내',
#   '네',
#   '공',
#   '을',
#   '다시',
#   '줍다',
#   '넌',
#   '내다',
#   '무얼',
#   '보답',
#   '줄',
#   '래'],
#  ['네',
#   '가지',
#   '고',
#   '싶다',
#   '건',
#   '다',
#   '착하다',
#   '개구리',
#   '야',
#   '라며',
#   '공주',
#   '말',
#   '내',
#   '옷',
#   '이나',
#   '내',
#   '진주',
#   '나',
#   '보석',
#   '아니다',
#   '내',
#   '지금',
#   '쓰다',
#   '있다',
#   '황금',
#   '관',
#   '머리',
#   '쓰다',
#   '금관',
#   '네',
#   '원하다',
#   '줄',
#   '게'],
#  ['개구리', '대답'],
#  ['난',
#   '네',
#   '옷',
#   '진주',
#   '보석',
#   '이나',
#   '황금',
#   '관',
#   '금관',
#   '엔',
#   '관심',
#   '없다',
#   '날',
#   '좋아하다',
#   '네',
#   '친구',
#   '로',
#   '삼다',
#   '놀이',
#   '친구',
#   '말',
#   '이야',
#   '그리고',
#   '네',
#   '예쁘다',
#   '식사',
#   '테이블',
#   '옆',
#   '앉히다',
#   '네',
#   '예쁘다',
#   '황금',
#   '접시',
#   '에서',
#   '식사',
#   '해주다',
#   '네',
#   '예쁘다',
#   '컵',
#   '말다',
#   '수',
#   '있다',
#   '해주다',
#   '그리고',
#   '네',
#   '예쁘다',
#   '침대',
#   '에서',
#   '재우다',
#   '만약',
#   '내',
#   '걸',
#   '약속',
#   '해주다',
#   '내',
#   '아래',
#   '로',
#   '내려가다',
#   '네',
#   '황금',
#   '공',
#   '을',
#   '가지',
#   '고',
#   '올라오다'],
#  ['응',
#   '그렇다',
#   '공주',
#   '말',
#   '만약',
#   '내',
#   '공',
#   '만',
#   '다시',
#   '가져다주다',
#   '네',
#   '원하다',
#   '것',
#   '을',
#   '다',
#   '들어주다'],
#  ['하지만', '공주', '속', '으론', '생각'],
#  ['흥',
#   '놀다',
#   '있다',
#   '개구리',
#   '주제',
#   '넌',
#   '그냥',
#   '다른',
#   '개구리',
#   '처럼',
#   '개골개골',
#   '울다',
#   '물',
#   '에서나',
#   '살',
#   '아',
#   '네까짓',
#   '게',
#   '어떻다',
#   '인간',
#   '친구',
#   '되다',
#   '수',
#   '있다',
#   '말',
#   '이니'],
#  ['어째', '든', '개구리', '이렇다', '약속', '을', '받다', '고개', '물속', '넣다', '잠수'],
#  ['잠시', '후', '개구리', '입', '가득', '공', '을', '물다', '물', '위로', '올라오다'],
#  ['개구리', '잔디밭', '위로', '공', '을', '던지다'],
#  ['자신', '예쁘다', '놀이', '공', '을', '번', '더', '보다', '공주', '뛰다', '듯이', '기쁘다'],
#  ['그래서', '공', '을', '줍다', '잽싸다', '도망가다', '버리다'],
#  ['기다리다',
#   '기다리다',
#   '개구리',
#   '말',
#   '나르다',
#   '데리',
#   '고',
#   '가야',
#   '지',
#   '난',
#   '너',
#   '처럼',
#   '달리다',
#   '수',
#   '없다'],
#  ['하지만',
#   '개구리',
#   '개골개골',
#   '개골개골',
#   '외치다',
#   '대다',
#   '소리',
#   '공주',
#   '따라잡다',
#   '만큼',
#   '크다',
#   '들다',
#   '과연',
#   '도움',
#   '되어다'],
#  ['아니다', '공주', '그', '말', '을', '들어주다', '리가', '없다'],
#  ['실제',
#   '로',
#   '공주',
#   '잽싸다',
#   '집',
#   '돌아오다',
#   '다음',
#   '다시',
#   '자신',
#   '우물',
#   '로',
#   '돌아가다',
#   '불쌍하다',
#   '개구리',
#   '일랑은',
#   '완전하다',
#   '잊다',
#   '말다'],
#  ['다음',
#   '날',
#   '공주',
#   '왕',
#   '신하',
#   '함께',
#   '식탁',
#   '앉다',
#   '자신',
#   '예쁘다',
#   '황금',
#   '접시',
#   '담기다',
#   '음식',
#   '을',
#   '먹다',
#   '있다',
#   '대리석',
#   '계단',
#   '을',
#   '오르다',
#   '소리',
#   '첨벙',
#   '첨벙',
#   '첨벙',
#   '첨벙',
#   '울리다',
#   '다가오다',
#   '것',
#   '이다'],
#  ['그', '소리', '계단', '꼭대기', '까지', '다다르다', '누군가', '문', '을', '똑똑', '노크', '소리치다'],
#  ['공주', '막내', '공주', '저', '에요', '문', '을', '열다'],
#  ['누군지',
#   '보다',
#   '달려가다',
#   '공주',
#   '문',
#   '을',
#   '열다',
#   '때',
#   '어마나',
#   '세상',
#   '문',
#   '앞',
#   '어제',
#   '그',
#   '개구리',
#   '앉다',
#   '있다',
#   '뭐',
#   '예요'],
#  ['그래서',
#   '공주',
#   '문',
#   '을',
#   '사정없이',
#   '닫다',
#   '버리다',
#   '허둥대다',
#   '다시',
#   '자리',
#   '로',
#   '오다',
#   '식사',
#   '계속',
#   '공주',
#   '너무나도',
#   '놀란',
#   '건',
#   '사다'],
#  ['누가', '보다', '공주', '얼굴', '붉으락', '푸르락', '게', '보이다'],
#  ['그래서', '왕', '말'],
#  ['딸애',
#   '야',
#   '왜',
#   '그렇다',
#   '문',
#   '앞',
#   '에서',
#   '너',
#   '데려가다',
#   '거인',
#   '이라도',
#   '보다',
#   '게',
#   '냐'],
#  ['아', '알다', '공주', '말', '거인', '아니다', '구역질', '나', '개구리', '마리', '야'],
#  ['개구리', '왜', '너', '부르다', '말', '이냐'],
#  ['아',
#   '그게',
#   '아빠',
#   '내',
#   '어제',
#   '숲',
#   '있다',
#   '우물가',
#   '앉다',
#   '공',
#   '을',
#   '만지작거리다',
#   '황금',
#   '공',
#   '을',
#   '우물',
#   '속',
#   '떨어뜨리다',
#   '말다',
#   '그래서',
#   '울',
#   '고',
#   '있다',
#   '개구리',
#   '공',
#   '을',
#   '다시',
#   '갖다',
#   '주다',
#   '그렇다',
#   '우기다',
#   '자기',
#   '내',
#   '친구',
#   '로',
#   '삼다',
#   '달라',
#   '고',
#   '약속',
#   '해달라다',
#   '거야',
#   '하지만',
#   '개구',
#   '린',
#   '물',
#   '에서',
#   '살다',
#   '그런데',
#   '지금',
#   '저렇게',
#   '문',
#   '앞',
#   '있다',
#   '들이다',
#   '보내다',
#   '달라',
#   '며'],
#  ['그렇다', '사이', '개구리', '똑똑', '두', '번째', '노크', '소리', '치고', '있다'],
#  ['공주', '님', '막내', '공주', '님'],
#  ['제', '게', '문', '을', '열다'],
#  ['어제', '시원하다', '분수', '대', '옆', '물가', '에서'],
#  ['제', '게', '말씀', '을', '그', '새', '잊다', '건', '아니다'],
#  ['공주', '님', '막내', '공주', '님'],
#  ['어서', '문', '을', '열다'],
#  ['그러자', '왕', '말씀'],
#  ['약속', '지키다', '있다', '게다', '어서', '가다', '그', '분', '을', '들이다', '거', '라'],
#  ['공주',
#   '마지못하다',
#   '가다',
#   '문',
#   '을',
#   '열다',
#   '개구리',
#   '폴짝',
#   '폴짝',
#   '뛰다',
#   '안',
#   '들어오다',
#   '선',
#   '공주',
#   '님',
#   '뒤',
#   '쫓다',
#   '발짝',
#   '발짝',
#   '드디어',
#   '공주',
#   '의자',
#   '에까지',
#   '오다',
#   '거기',
#   '서',
#   '개구리',
#   '소리치다'],
#  ['당신', '옆', '올려주다'],
#  ['공주', '머뭇거리다', '마침내', '왕', '께서', '그', '리하', '라', '이르다'],
#  ['공주',
#   '의자',
#   '일단',
#   '번',
#   '착석',
#   '을',
#   '하자',
#   '개구리',
#   '이번',
#   '엔',
#   '식탁',
#   '위로',
#   '가다',
#   '싶다'],
#  ['식탁', '위', '에서', '이제', '개구리', '말'],
#  ['당신',
#   '예쁘다',
#   '황금',
#   '접시',
#   '담기다',
#   '음식',
#   '을',
#   '우리',
#   '함께',
#   '먹다',
#   '수',
#   '있다',
#   '그',
#   '황금',
#   '접시',
#   '더',
#   '내',
#   '쪽',
#   '밀다'],
#  ['공주',
#   '그리다',
#   '하지만',
#   '속',
#   '으론',
#   '절대',
#   '그리다',
#   '싶다',
#   '않다',
#   '눈치',
#   '이다',
#   '건',
#   '당',
#   '연',
#   '지사'],
#  ['개구리', '자신', '먹다', '걸', '즐겁다'],
#  ['하지만',
#   '공주',
#   '음식',
#   '입',
#   '입',
#   '마다',
#   '정말',
#   '이지',
#   '숨',
#   '막히다',
#   '죽',
#   '을',
#   '지경',
#   '이다'],
#  ['마침내', '개구리', '말'],
#  ['이제',
#   '만족하다',
#   '먹다',
#   '피곤하다',
#   '나르다',
#   '당신',
#   '예쁘다',
#   '방',
#   '데려가다',
#   '주다',
#   '당신',
#   '예쁘다',
#   '비단',
#   '침대',
#   '자리',
#   '펴다',
#   '우리',
#   '같이',
#   '눕다',
#   '자다'],
#  ['공주', '급기야', '눈물', '을', '터뜨리다'],
#  ['차갑다',
#   '개구리',
#   '만',
#   '지고',
#   '싶다',
#   '않다',
#   '자신',
#   '예쁘다',
#   '깨끗하다',
#   '이쁜이',
#   '침대',
#   '에서',
#   '재우다',
#   '넘다',
#   '싫다',
#   '때문',
#   '죠'],
#  ['하지만', '왕', '께서', '역정', '을', '내시', '면', '말씀'],
#  ['너', '도와주다', '분', '께', '무슨', '무례', '란', '말', '이냐'],
#  ['그래서', '공주', '개구리', '두', '손가락', '쥐다', '층', '가다', '방', '구석', '두다'],
#  ['하지만', '공주', '침대', '앉다', '개구리', '공주', '에게로', '기다', '말'],
#  ['나',
#   '피곤하다',
#   '네',
#   '옆',
#   '에서',
#   '자고',
#   '싶다',
#   '나르다',
#   '들다',
#   '올려주다',
#   '그렇다',
#   '않다',
#   '네',
#   '아버지',
#   '께',
#   '다',
#   '이르다',
#   '거야'],
#  ['그', '바람', '공주', '참다', '오다', '화가', '폭발', '하고', '말다'],
#  ['개구리', '집다', '벽', '에다', '사정없이', '내다', '말다'],
#  ['이제', '조용하다', '가증', '스런', '개구리', '야', '라며', '공주', '말'],
#  ['그런데', '바닥', '떨어지다', '개구리', '더', '이상', '개구리', '아니다', '거', '예요'],
#  ['어머나',
#   '세상',
#   '개구리',
#   '어디가',
#   '고',
#   '웬',
#   '아름답다',
#   '상냥하다',
#   '눈동자',
#   '지니다',
#   '왕자',
#   '님',
#   '서다',
#   '계시',
#   '지',
#   '뭐',
#   '예요'],
#  ['왕', '말씀', '따르다', '왕자', '이제', '공주', '연인', '이자', '남편', '되어다'],
#  ['그렇다',
#   '나서다',
#   '왕자',
#   '공주',
#   '에게',
#   '자신',
#   '어떻다',
#   '사악하다',
#   '마녀',
#   '마법',
#   '빠지다',
#   '되어다',
#   '그리고',
#   '그',
#   '마녀',
#   '공주',
#   '외',
#   '에는',
#   '아무',
#   '자신',
#   '왕',
#   '을',
#   '우물',
#   '에서',
#   '구',
#   '못',
#   '말',
#   '해주다'],
#  ['그', '다음', '날', '공주', '왕자', '함께', '왕자', '왕국', '갈다', '예정', '이다'],
#  ['그리고',
#   '같이',
#   '잠',
#   '을',
#   '자다',
#   '다음',
#   '날',
#   '아침',
#   '눈부시다',
#   '햇살',
#   '그',
#   '을',
#   '깨우다',
#   '마리',
#   '희다',
#   '말',
#   '끄다',
#   '마차',
#   '도착',
#   '말',
#   '머리',
#   '엔',
#   '흰색',
#   '타조',
#   '깃털',
#   '꽂다',
#   '있다',
#   '금줄',
#   '로',
#   '치렁치렁',
#   '몸',
#   '을',
#   '감싸다',
#   '말',
#   '들이다'],
#  ['말',
#   '바로',
#   '뒷',
#   '편',
#   '엔',
#   '왕자',
#   '님',
#   '충실하다',
#   '종인',
#   '헨리',
#   '남자',
#   '이름',
#   '타고',
#   '있다'],
#  ['자신',
#   '주인',
#   '왕자',
#   '님',
#   '개구리',
#   '로',
#   '변하다',
#   '버리다',
#   '너무도',
#   '비참하다',
#   '충실하다',
#   '헨리',
#   '남자',
#   '이름',
#   '왕자',
#   '종',
#   '늘다',
#   '비탄',
#   '슬픔',
#   '자신',
#   '심장',
#   '터지다',
#   '버리다',
#   '것',
#   '을',
#   '방지',
#   '위해',
#   '가슴',
#   '철',
#   '대',
#   '철로',
#   '되다',
#   '테두리',
#   '세',
#   '개',
#   '둘러매다',
#   '더랬',
#   '어',
#   '요'],
#  ['왕자',
#   '님',
#   '부부',
#   '왕자',
#   '님',
#   '왕국',
#   '태우다',
#   '갈다',
#   '마차',
#   '끌',
#   '고',
#   '온',
#   '충실하다',
#   '헨리',
#   '두',
#   '분',
#   '을',
#   '마차',
#   '태우다',
#   '드리다',
#   '훈',
#   '다시',
#   '뒷',
#   '좌석',
#   '가다',
#   '앉다'],
#  ['왕자',
#   '님',
#   '사악하다',
#   '마법',
#   '에서',
#   '해방',
#   '되다',
#   '게',
#   '헨리',
#   '왕자',
#   '님',
#   '종',
#   '늘다',
#   '너무도',
#   '기쁘다'],
#  ['마차',
#   '타고',
#   '가다',
#   '도중',
#   '중간',
#   '중간',
#   '왕자',
#   '님',
#   '자신',
#   '뒤',
#   '에서',
#   '무엇',
#   '인가가',
#   '마치',
#   '부서지다',
#   '듯',
#   '갈라지다',
#   '소리',
#   '들다'],
#  ['그래서', '뒤', '돌아보다', '소리치다'],
#  ['헨리', '왕자', '님', '종', '마차', '부서지다', '있다'],
#  ['아니다',
#   '주인',
#   '님',
#   '마차',
#   '아니다',
#   '제',
#   '가슴',
#   '에서',
#   '나',
#   '악기',
#   '소리',
#   '에요',
#   '왕자',
#   '님',
#   '개구리',
#   '로',
#   '변하다',
#   '우물',
#   '속',
#   '갇히다',
#   '때',
#   '제',
#   '슬픔',
#   '을',
#   '참다',
#   '못',
#   '하고',
#   '제',
#   '가슴',
#   '둘러매다',
#   '쇠테',
#   '철로',
#   '만들다',
#   '띠',
#   '에요'],
#  ['마차',
#   '가다',
#   '도중',
#   '또다시',
#   '그리고',
#   '번',
#   '더',
#   '또다시',
#   '뭔가',
#   '와장창',
#   '깨지다',
#   '소리',
#   '나다',
#   '그렇다',
#   '때',
#   '마다',
#   '왕자',
#   '님',
#   '이번',
#   '엔',
#   '정말',
#   '이지',
#   '마차',
#   '박살',
#   '나다',
#   '있다',
#   '생각'],
#  ['ㅋㅋㅋ',
#   '하지만',
#   '그건',
#   '자신',
#   '주인',
#   '왕자',
#   '님',
#   '마법',
#   '에서',
#   '풀다',
#   '행복하다',
#   '것',
#   '너무도',
#   '기쁘다',
#   '충직',
#   '종인',
#   '헨리',
#   '남자',
#   '이름',
#   '왕자',
#   '님',
#   '종',
#   '심장',
#   '용솟음',
#   '치면',
#   '서',
#   '쇠테',
#   '철로',
#   '만들다',
#   '띠',
#   '망치',
#   '처럼',
#   '두드리다',
#   '바람',
#   '내다',
#   '소리',
#   '이다']]
