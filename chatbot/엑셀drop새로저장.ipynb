# %%
import numpy as np
import pandas as pd
import openpyxl
df = pd.read_excel('웰니스부정.xlsx')
df
# Out:
#                                            Unnamed: 0  0
# 0     제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.  0
# 1                            더 이상 내 감정을 내가 컨트롤 못 하겠어.  0
# 2                                                 NaN  0
# 3                                                 NaN  0
# 4                                                 NaN  0
# ...                                               ... ..
# 5226             한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.  0
# 5227                            자고 나면 괜찮을 줄 알았는데 비슷해…  0
# 5228                                 지금도 상태가 계속 안 좋아.  0
# 5229                                              NaN  0
# 5230                    나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.  0
#
# [5231 rows x 2 columns]

# %%
df_new = df.dropna(axis=0)
df_new
# Out:
#                                            Unnamed: 0  0
# 0     제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.  0
# 1                            더 이상 내 감정을 내가 컨트롤 못 하겠어.  0
# 5                          작년 가을부터 감정조절이 잘 안 되는 거 같아.  0
# 6                           예전에 비해서 인내심이 너무 짧아진 거 같아.  0
# 7                               더 이상 혼자서는 감정조절을 못하겠어.  0
# ...                                               ... ..
# 5225                       이러다 말겠지, 했는데… 전혀 나아지질 않아요.  0
# 5226             한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.  0
# 5227                            자고 나면 괜찮을 줄 알았는데 비슷해…  0
# 5228                                 지금도 상태가 계속 안 좋아.  0
# 5230                    나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.  0
#
# [3420 rows x 2 columns]

# %%
df_new.to_excel('웰니스부정2.xlsx', index=False)
