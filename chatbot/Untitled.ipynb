# %%
import os
import sys
import urllib.request
import json
import re

# %%
client_id = "jidTcEIw6D0PQlS1xKsi"
client_secret = "O7v0zNkhPc"
encText = urllib.parse.quote("서울 ** 피크닉")
url = "https://openapi.naver.com/v1/search/blog.json?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)


response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

print("**")
text_data = response_body.decode('utf-8')
json_data = json.loads(text_data)

for x in json_data['items']:
    result = re.sub('<.+?>', '', x['title'], 0, re.I | re.S)
    print(result)
# Out:
# **
# 서울 피크닉 전시회 : 강렬한 페더팝스트의 무대들
# 서울 데이트 선유도공원에서 피크닉했지
# 언제가도 좋은 한강 노들섬. 서울 피크닉 라이딩 추천장소
# [서울] 한강 피크닉 + 힙지로 을지로3가역 을지육점 특수부위 냠냠
# 서울 피크닉 전시회 명상 Mindfulness 후기
# [서울] 올림픽공원 나홀로 나무, 서울피크닉 대여
# 서울 피크닉 뚝섬 텐트 대여 힐링텐트 후기&amp; 장소 꿀팁
# [서울 한강 피크닉] 사진찍기 좋은 곳. 반포한강공원 세빛섬...
# 한강피크닉 서울호텔패키지로 이용했어요 솔직한 후기
# 서울근교 당일치기 피크닉 인천대공원 너나들이 캠핑장

# %%
client_id = "jidTcEIw6D0PQlS1xKsi"
client_secret = "O7v0zNkhPc"
encText = urllib.parse.quote("서울 ** 피크닉")
url = "https://openapi.naver.com/v1/search/blog.json?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)


response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

print("**")
text_data = response_body.decode('utf-8')
json_data = json.loads(text_data)

for x in json_data['items']:
    result = re.sub('<.+?>', '', x['title'], 0, re.I | re.S)
    print(result)
# Out:
# {
# "lastBuildDate": "Tue, 15 Sep 2020 11:04:50 +0900",
# "total": 106542,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>서울</b> <b>피크닉</b> 전시회 : 강렬한 페더팝스트의 무대들",
# "link": "https:\/\/blog.naver.com\/dbrud8829?Redirect=Log&logNo=221688110312",
# "description": "<b>서울</b> <b>피크닉</b> 전시회 : 강렬한 페더팝스트의 무대들 다녀온 지가 언젠데 지금 올리는 ‼️<b>서울</b> <b>피크닉</b> 전시회 후기‼️ 저번에 친구 인스타 보다가 piknic 이라고 하는 전시회가 있길래 기억해뒀다가 <b>서울</b>여행... ",
# "bloggername": "갱유의 Connecting the dots",
# "bloggerlink": "https://blog.naver.com/dbrud8829",
# "postdate": "20191025"
#
# },
# {
# "title": "<b>서울</b> 데이트 선유도공원에서 <b>피크닉</b>했지",
# "link": "https:\/\/blog.naver.com\/qkrgkdms1993?Redirect=Log&logNo=222049330268",
# "description": "선유도공원은 <b>서울</b> 데이트, <b>피크닉</b>으로 참 좋은 장소에요. 넓다래서 사회적 거리두기에 함께하면서, 자유를 느낄 수 있습니다. 초록이 주는 싱그러움과 따뜨,, 아니 뜨거,, 아니 그늘 아래에선 괜,,찮은 시간을... ",
# "bloggername": "HAEUN IS GARDEN",
# "bloggerlink": "https://blog.naver.com/qkrgkdms1993",
# "postdate": "20200803"
#
# },
# {
# ...
