# %%
from bs4 import BeautifulSoup
import requests
import urllib.request

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}

url = "https://place.map.kakao.com/10305191"

# %%
response = requests.get(url, headers = headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")   # response.text면 글 깨짐
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>덕수궁 | 카카오맵</title>
# <meta content="덕수궁" property="og:title"/>
# <meta content="카카오맵" property="og:site_name"/>
# <meta content="서울 중구 세종대로 99 (정동 5-1)" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="http://map3.daum.net/staticmap/og?type=place&amp;srs=wcongnamul&amp;size=400x200&amp;m=494455%2C1129453" property="og:image"/>
# <meta content="https://place.map.kakao.com/10305191" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="덕수궁" name="twitter:title"/>
# <meta content="서울 중구 세종대로 99 (정동 5-1)" name="twitter:description"/>
# <meta content="http://map3.daum.net/staticmap/og?type=place&amp;srs=wcongnamul&amp;size=400x200&amp;m=494455%2C1129453" name="twitter:image"/>
# <link href="//t1.daumcdn.net/localimg/localimages/07/common/kakaomap_favicon.ico" rel="shortcut icon"/>
# <link href="//t1.daumcdn.net/kakaomapweb/place/jscss/pc.efe78505.css" rel="stylesheet" type="text/css">
# </link></head>
# <body>
# <div id="kakaoIndex">
# <a href="#kakaoBody">본문 바로가기</a>
# <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="wrap_mapdetail" id="kakaoWrap"><!-- 스크롤이 내려 왔을 때 클래스 lbar_on  -->
# <div id="wrapMinidaum"></div>
# </div>
# <div id="daumWrap" style="display:none;">
# <div id="daumContent">
# <div id="shareContainer"></div>
# </div>
# </div>
# <script src="//ssl.daumcdn.net/dmaps/map_js_init/v3.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/daumtop_deco/socialshare/socialshare_pc-2.4.1.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/adfit/static/ad-native.min.js" type="text/javascript"></script>
# <script>
#         window.ENV = 'PROD';
#         window.browserversion = 'chrome85';
#
#         // 티아라 초기화
#         try {
#             TiaraTracker.getInstance().init({
#                 svcDomain: 'place.map.kakao.com',
#                 deployment: window.ENV === 'PROD' ? 'production' : 'dev'
#             });
#         } catch(e) {}
#         window.needFiy = 'true';
#         window.needBlogReview = 'true';
#         window._cp = '';
#     </script>
# <script src="//s1.daumcdn.net/svc/attach/U0301/cssjs/mm/1482483925476/Chart.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/kakaomapweb/place/jscss/pc.2018109d.js" type="text/javascript"></script>
# <!--
#     <script>
#         var minidaum_options = {
#             disableTracker: true, // 미니다음에서 tiara 사용안함
#             bgType: "white",
#             enableLogoutRetun: true,
#             returnUrl: '',
#             disableHotissue: true,
#             disableLogo:true,
#             enableShield: false
#         };
#     </script>
#     <script async src="//go.daum.net/jsa_minidaum_pc.daum" charset="utf-8" type="text/javascript"></script>
#     -->
# </body>
# </html>

# %%
# soup에는 "덕수궁" 없음

names = soup.findAll('span', {'class': '_3XamX'})   #  <- F12에서 "덕수궁"위치

# %%
print(names)
# Out:
# []

# %%
url = "https://map.naver.com/v5/entry/place/11571730"
req = urllib.request.urlopen(url)
res = req.read()
 
soup = BeautifulSoup(res,'html.parser') 
keywords = soup.find_all('span',class_='_9bFMx') 
print(keywords)
# Out:
# []

# %%
from selenium import webdriver
# from selenium.common.exceptions import NoSuchElementException
import time

# driver
driver = webdriver.Chrome(
    executable_path="chromedriver.exe")
driver.get("http://v4.map.naver.com")

# close
driver.find_elements_by_css_selector("button.btn_close")[1].click()

# write
search_box = driver.find_element_by_css_selector("input#search-input")
search_box.send_keys("서울 관광지")

# click
search_button = driver.find_element_by_css_selector("button.spm")
search_button.click()

# index
index = 0

for n in range(1, 20):
    # container
    time.sleep(1)
    stores = driver.find_elements_by_css_selector("div.lsnx")
    for store in stores:
        name = store.find_element_by_css_selector("dt>a").text
        addr = store.find_element_by_css_selector("dd.addr").text
        try:
            phone = store.find_element_by_css_selector("dd.tel").text
        except:
            phone = "NoExist"
        print(index, ',', name, ',', addr, ',', phone)
        index = index+1

    # browse page
    page_bar = driver.find_elements_by_css_selector('div.paginate > *')

    # load more page using pgbar
    try:
        if n % 5 != 0:
            page_bar[(n % 5)+1].click()
        else:
            page_bar[6].click()
    except:
        print("EOC")
        break

# close
driver.close()
# Out:
# 0 , 롯데월드 , 서울특별시 송파구 올림픽로 240 지번 , 1661-2000
# 1 , 북촌 한옥마을 , 서울특별시 종로구 계동길 37 지번 , 02-2133-1372
# 2 , 하늘공원 , 서울특별시 마포구 하늘공원로 95 지번 , 02-300-5501
# 3 , 낙산공원 , 서울특별시 종로구 낙산길 41 지번 , 02-743-7985
# 4 , 가로수길 , 서울특별시 강남구 신사동 , NoExist
# 5 , 북서울꿈의숲 , 서울특별시 강북구 월계로 173 지번 , 02-2289-4001
# 6 , 인왕산 , 서울특별시 종로구 무악동 산2-1 , NoExist
# 7 , 선유도공원 , 서울특별시 영등포구 선유로 343 지번 , 02-2631-9368
# 8 , N서울타워 , 서울특별시 용산구 남산공원길 105 지번 , 02-3455-9277
# 9 , 창덕궁 , 서울특별시 종로구 율곡로 99 지번 , 02-3668-2300
# 10 , 이화마을 , 서울특별시 종로구 이화장길 70-11 지번 , NoExist
# 11 , 쌈지길 , 서울특별시 종로구 인사동길 44 쌈지길 지번 , 02-736-0088
# 12 , 창경궁 , 서울특별시 종로구 창경궁로 185 창경궁 지번 , 02-762-4868
# 13 , 서울어린이대공원 , 서울특별시 광진구 능동로 216 지번 , 02-450-9311
# 14 , 서울숲 , 서울특별시 성동구 뚝섬로 273 지번 , 02-460-2905
# 15 , 올림픽공원 , 서울특별시 송파구 올림픽로 424 지번 , 02-410-1114
# 16 , 여의도 한강공원 , 서울특별시 영등포구 여의동로 330 한강사업본부 여의도안내센터 지번 , 02-3780-0561
# 17 , 도봉산 , 서울특별시 도봉구 도봉동 , 02-954-2566
# 18 , 보라매공원 , 서울특별시 동작구 여의대방로20길 33 지번 , 02-2181-1196
# 19 , 광화문 , 서울특별시 종로구 효자로 12 국립고궁박물관 지번 , 02-3700-3901
# 20 , 남산골한옥마을 , 서울특별시 중구 퇴계로34길 28 남산골한옥마을 지번 , 02-2261-0517
# 21 , 덕수궁 , 서울특별시 중구 세종대로 99 덕수궁 지번 , 02-771-9951
# 22 , 월드컵공원 , 서울특별시 마포구 하늘공원로 108-1 지번 , 02-300-5500
# 158 , 석파정 , 서울특별시 종로구 부암동 , NoExist
# 159 , 문래근린공원 , 서울특별시 영등포구 문래동3가 66 , 02-2670-3755
# 160 , 중계마을 , 서울특별시 노원구 중계본동 104-3 , NoExist
# 161 , 애니멀 뮤지엄 더쥬 , 서울특별시 강동구 양재대로 1299 우용빌딩 2층 지번 , 02-470-2003
# 162 , 광나루자전거공원 , 서울특별시 강동구 천호동 483-8 , 02-120
# 163 , 서울함 공원 , 서울특별시 마포구 마포나루길 407 지번 , 02-332-7500
# 164 , 영등포공원 , 서울특별시 영등포구 영등포동 , 02-2670-3717
# 165 , 경복궁 근정전 , 서울특별시 종로구 세종로 , NoExist
# 166 , 구암근린공원 , 서울특별시 강서구 허준로5길 42 지번 , 02-2600-4196
# 167 , 하늘공원메타세콰이어길 , 서울특별시 마포구 상암동 , NoExist
# 168 , 이상의집 , 서울특별시 종로구 자하문로7길 18 지번 , 070-8837-8374
# 169 , 을지로노가리골목 , 서울특별시 중구 을지로 129 을지로3가역 3호선 지번 , NoExist
# 170 , 환구단 , 서울특별시 중구 소공동 , NoExist
# 171 , 대모산 , 서울특별시 강남구 개포동 대모산 , NoExist
# 172 , 구룡산 , 서울특별시 서초구 염곡동 , 02-2155-6860
# 173 , 살곶이체육공원 , 서울특별시 성동구 사근동 102-16 , 02-2286-6090
# 174 , 피규어뮤지엄w , 서울특별시 강남구 선릉로158길 3 Ys Roo 지번 , 02-512-8865
# 175 , 창덕궁 낙선재 , 서울특별시 종로구 와룡동 , NoExist
# 176 , 브릭캠퍼스 서울 , 서울특별시 성동구 서울숲2길 32-14 갤러리아포레 G층 지번 , 02-2261-1393
# 177 , 정동전망대 , 서울특별시 중구 덕수궁길 15 지번 , NoExist
# 178 , 영휘원 , 서울특별시 동대문구 청량리동 , 02-962-0556
# 179 , 북한산둘레길21구간 , 서울특별시 강북구 우이동 , NoExist
# 180 , 헌인릉인릉 , 서울특별시 서초구 헌인릉길 36-10 지번 , 02-445-0347
# 181 , 삼전도비 , 서울특별시 송파구 잠실로 148 지번 , 042-481-4650
# 182 , 서울숲곤충식물원 , 서울특별시 성동구 성수동1가 685-715 , 02-460-2905
# 183 , 박물관은살아있다 인사동점 , 서울특별시 종로구 인사동길 12 지번 , 02-2034-0600
# 184 , 백범김구기념관 , 서울특별시 용산구 임정로 26 지번 , 02-799-3400
# 185 , 혜화문 , 서울특별시 종로구 혜화동 , NoExist
# 186 , 최순우옛집 , 서울특별시 성북구 성북로15길 9 지번 , 02-3675-3402
# 187 , 경교장 , 서울특별시 종로구 평동 , 02-735-2038
# 188 , 세종대왕기념관 , 서울특별시 동대문구 회기로 56 지번 , 02-969-8851
# 189 , 경복궁 경회루 , 서울특별시 종로구 사직로 161 지번 , 02-3700-3900

# %%
import os
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

##############################################################  ############
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = "chromedriver"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기

# %%
def main():
    global driver, load_wb, review_num

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

    # 검색할 목록
    place_infos = ['강남 명소']

    for i, place in enumerate(place_infos):
        # delay
        if i % 4 == 0 and i != 0:
            sleep(5)
        print("**", i)
        search(place)

    driver.quit()
    print("finish")

# %%
def search(place):
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, place_lists)
    search_area.clear()

    # 우선 더보기 클릭해서 2페이지
    try:
        driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        # 2~ 5페이지 읽기
        for i in range(2, 6):
            # 페이지 넘기기
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list

            crawling(place, place_lists)

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()

# %%
def crawling(place, place_lists):
    """
    페이지 목록을 받아서 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    """

    while_flag = False
    for i, place in enumerate(place_lists):
        # 광고에 따라서 index 조정해야함
        #if i >= 3:
         #   i += 1

        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
        sleep(1)

        print('####', place_name)

        # 첫 페이지
        extract_review(place_name)

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 페이지 버튼 누르기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name)
                idx += 1
            driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
            sleep(1)
            extract_review(place_name) # 리뷰 추출
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        # 그 이후 페이지
        while True:
            idx = 4
            try:
                page_num = len(driver.find_elements_by_class_name('link_page'))
                for i in range(page_num-1):
                    driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                    sleep(1)
                    extract_review(place_name)
                    idx += 1
                driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 10페이지 이상으로 넘어가기 위한 다음 버튼 클릭
                sleep(1)
                extract_review(place_name) # 리뷰 추출
            except (NoSuchElementException, ElementNotInteractableException):
                print("no review in crawling")
                break

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환

# %%
def extract_review(place_name):
    global driver

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span') # 리뷰
            rating = review.select('.grade_star > em') # 별점
            val = ''
            if len(comment) != 0:
                if len(rating) != 0:
                    val = comment[0].text + '/' + rating[0].text.replace('점', '')
                else:
                    val = comment[0].text + '/0'
                print(val)

    else:
        print('no review in extract')
        ret = False

    return ret


if __name__ == "__main__":
    main()
# Out:
# ##### 0
# #### 압구정로데오거리
# 최고예요/5
# 압구정로데오 /5
# 가끔 쇼핑하러 오는곳/3
# 최고예요/5
# 내 아지트! ^^vV/4
# 압구정로데오 맛집 카페  *달콤커피*/5
# no review in crawling
# no review in crawling
# #### 서울 선릉과 정릉
# 좋아요/4
# 최고예요/5
# 최고예요/5
# 입장 시간 위의 안내와는 달라요. 전화 해보고 가세요. 지금 시즌은 오후 4시반에 입장 마감해요~ 수정이 필요해 보이네요/4
# 입장시간 수정해라 아오/1
# 굿/5
# 최고예요/5
# 산책하기도 좋고 마음이 편해져요 /5
# 좋아요/4
# 강남 한복판에 이런 곳이! 강남구민 500원.  종종 가야겠다, 입구는 왜 더 멀어졌을까.. 중간에 계단이 있어 유모차는 입구에 보관해야할듯. /5
# 보통이에요/3
# 나무가 멋지고 걷기 좋음./5
# 929/0
# 역사공부도 되지만 산책하기도 좋은 곳. 생각보다 여름에 가면 나무가 울창하다./0
# 도시의 공원 ^^/0
# /0
# ♥/0
# 일하다가 바람쐬고싶을때 걷는곳~/0
# 벗 꽃 구 경/0
# 입장료 있음  왕의 장례식.방법이  잘되어있음/0
# 여친이랑 같이 가보렴 은근 좋단다./0
# 긴 겨울 지나 오랫만에 선정릉을 찾다../0
# 선릉과 정릉을 합쳐 선정릉이라고하며, 선릉으로 많이 알려짐. 조선 9대 성종과 계비 정현왕후의 릉인 선릉과 11대 중종의 릉인 정릉이 있다/0
# 좋아요/4
# 서울에 사시는 분들은 조선왕릉 갈때 여기가 제일 좋을 것 같네요/5
# 가볼만 해여~ 가기 전에 릉에 대해 조사해서 가면 느낌이 남다를듯/5
# 차분해지는 그런느낌 경건해지고 그렇습니다`~/5
# 입장료가 있긴 하지만.. 서울 도심에서 여유 찾기에 정말 좋아요./4
# 주변풍경이 너무 좋습니다, 봄, 여름 다 다 좋을 듯 합니다 ㅋㅋ/5
# 한번쯤 가보면 좋을 것 같아요. /4
# 가볼만 합니다./4
# 조용히 사책할떄 좋은 곳  같아여`~/3
# 역사를 탐구하는 정신을 가지고 싶다묘ㅕㄴ/4
# 가족과 함께 가야면 좋을듯~! /5
# 가볼만 한 곳이예요~/5
# 무료인줄 알고 갔는데 요금을 내더라구요;;; 동네 주민들도 애견들과 함께 많이 찾아오더군요~ 도심속에서 조용하게 사색에 잠기기 좋은 곳이예요~/4
# no review in crawling
# #### 신사동가로수길
# 조금 아쉬워요/2
# 보통이에요/3
# 최고예요/5
# 최고예요/5
# 올드한 거리/2
# 가격상관안하면 괜찮은곳이고 굳이 이가격에 이걸먹어야되나 싶기도한데 디저트카페가격이 거기서 거기니깐...ㅎㅎ/4
# 그냥 의류매장 많아요~ 라인스토어도 있고요/4
# 특색있는 장소에서 이젠 그저그런 번화가 중 하나로 바뀐곳/1
# 가로수는 어디에.../3
# 보통이에요/3
# 좋은 구경 많이 하고~/4
# 보통이에요/3
# 별루 별루.../1
# 허세의 거리/1
# 그저그렇데요/1
# 특색이 없어졌음 일반번화가와 차이가 없음/1
# 역시.. 개중에 맛있는집도있긴하만 너무 비쌈/1
# 어딘가 불편하게 느껴지는 곳이더니 아래 평들이 그 느낌을 설명해주는군요. 여기보다는 죽전 갑니다~/2
# 임대료만 허벌나게 올라서 정작 문화 업소는 다 달아나고 물먹이는 업소만 즐비하게 개업을 한답니다. 역시 인테리어 업자와 간판업자 부동산만 배가 부르고 있습니다./1
# 비싸고 그저그런 맛과 품질의 커피숍과 가게, 와인바들만 즐비하는데 왜들 오시는건지.../2
# 필수 데이트 코스/5
# no review in crawling
# 특색이 없어졌음 일반번화가와 차이가 없음/1
# 역시.. 개중에 맛있는집도있긴하만 너무 비쌈/1
# 어딘가 불편하게 느껴지는 곳이더니 아래 평들이 그 느낌을 설명해주는군요. 여기보다는 죽전 갑니다~/2
# 임대료만 허벌나게 올라서 정작 문화 업소는 다 달아나고 물먹이는 업소만 즐비하게 개업을 한답니다. 역시 인테리어 업자와 간판업자 부동산만 배가 부르고 있습니다./1
# 비싸고 그저그런 맛과 품질의 커피숍과 가게, 와인바들만 즐비하는데 왜들 오시는건지.../2
# no review in crawling
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-40-17f02878e994> in <module>
#      31
#      32 if __name__ == "__main__":
# ---> 33     main()
#
# <ipython-input-37-603c91f764b9> in main()
#      13             sleep(5)
#      14         print("#####", i)
# ---> 15         search(place)
#      16
#      17     driver.quit()
#
# <ipython-input-38-edc51504b8df> in search(place)
#      15
#      16     # 검색된 첫 페이지 장소 목록 크롤링하기
# ---> 17     crawling(place, place_lists)
#      18     search_area.clear()
#      19
#
# <ipython-input-39-643ebfb54f21> in crawling(place, place_lists)
#      15
#      16         detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
# ---> 17         driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
#      18         driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
#      19         sleep(1)
#
# C:\ANACONDA\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ANACONDA\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# C:\ANACONDA\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ANACONDA\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[4]/div[5]/div[4]/a[1]"}
#   (Session info: headless chrome=85.0.4183.102)
